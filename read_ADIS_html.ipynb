# %%
# df = pandas.read_excel(open('your_xls_xlsx_filename','rb'), sheetname=2)
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
import math
import os
from datetime import *

#changes displaying
sns.set_context("poster")

# %%
#BDR A321
filepath="//fr-vfiler090/V390_DATA_DFDR/nasgroup/ADIS/ADIS_Monitoring/xml/"

file_name='A321EIS_CAT3.csv'

# %%
liste_file=os.listdir(filepath)
print (liste_file)
# Out:
# ['K0001V1724ADISActivatedStates-2019-06-06.xml', 'U1824V0172ADISActivatedStates-2019-06-13.xml', 'K0001V1725ADISActivatedStates-2019-06-11.xml', 'F6101V0460_NO-ADISActivatedStates-2019-06-13.xml', 'N6464V0234ADISActivatedStates-2019-06-13.xml', 'P1795V0301_NO-ADISActivatedStates-2019-06-13.xml', 'V0059V0319ADISActivatedStates-2019-06-13.xml', 'L0001V1204_NO-ADISActivatedStates-2019-06-13.xml', 'L0001V1205_NO-ADISActivatedStates-2019-06-13.xml', 'U1824V0173ADISActivatedStates-2019-06-14.xml', 'P1888V0082ADISActivatedStates-2019-06-14.xml', 'P1795V0302ADISActivatedStates-2019-06-14.xml', 'V0001V0628_NO-ADISActivatedStates-2019-06-14.xml', 'F6101V0461_NO-ADISActivatedStates-2019-06-14.xml', 'N6464V0235_NO-ADISActivatedStates-2019-06-14.xml', 'V0059V0320ADISActivatedStates-2019-06-14.xml', 'U1824V0174ADISActivatedStates-2019-06-17.xml', 'U1824V0175ADISActivatedStates-2019-06-17.xml', 'P1888V0083ADISActivatedStates-2019-06-18.xml', 'N6464V0236ADISActivatedStates-2019-06-18.xml', 'V0001V0630_NO-ADISActivatedStates-2019-06-18.xml', 'V0001V0629ADISActivatedStates-2019-06-17.xml', 'U1824V0176ADISActivatedStates-2019-06-18.xml', 'U1824V0177ADISActivatedStates-2019-06-18.xml', 'P1888V0084ADISActivatedStates-2019-06-19.xml', 'U1824V0178ADISActivatedStates-2019-06-19.xml', 'N6464V0237_NO-ADISActivatedStates-2019-06-19.xml', 'U1824V0179ADISActivatedStates-2019-06-20.xml', 'N6464V0238ADISActivatedStates-2019-06-20.xml', 'P1888V0085ADISActivatedStates-2019-06-20.xml', 'P1888V0086ADISActivatedStates-2019-06-21.xml', 'N6464V0239ADISActivatedStates-2019-06-21.xml', 'P1795V0303_NO-ADISActivatedStates-2019-06-16.xml', 'P1795V0305_NO-ADISActivatedStates-2019-06-18.xml', 'P1795V0304_NO-ADISActivatedStates-2019-06-17.xml', 'P1795V0308_NO-ADISActivatedStates-2019-06-22.xml', 'P1795V0309_NO-ADISActivatedStates-2019-06-23.xml', 'P1795V0306_NO-ADISActivatedStates-2019-06-19.xml', 'P1795V0310_NO-ADISActivatedStates-2019-06-23.xml', 'V0059V0322ADISActivatedStates-2019-06-17.xml', 'V0059V0321ADISActivatedStates-2019-06-16.xml', 'V0059V0325ADISActivatedStates-2019-06-19.xml', 'U1824V0168ADISActivatedStates-2019-06-11.xml', 'V0059V0324ADISActivatedStates-2019-06-18.xml', 'V0059V0323ADISActivatedStates-2019-06-17.xml', 'V0059V0326ADISActivatedStates-2019-06-20.xml', 'V0059V0327_NO-ADISActivatedStates-2019-06-22.xml', 'U1824V0169ADISActivatedStates-2019-06-11.xml', 'U1824V0170ADISActivatedStates-2019-06-12.xml', 'U1824V0171ADISActivatedStates-2019-06-12.xml', 'V0059V0328ADISActivatedStates-2019-06-23.xml', 'V0059V0329ADISActivatedStates-2019-06-23.xml', 'N6464V0231ADISActivatedStates-2019-06-07.xml', 'V0001V0631_NO-ADISActivatedStates-2019-06-24.xml', 'P1888V0087ADISActivatedStates-2019-06-24.xml', 'N6464V0240ADISActivatedStates-2019-06-25.xml', 'U1824V0180ADISActivatedStates-2019-06-25.xml', 'P1795V0311_NO-ADISActivatedStates-2019-06-25.xml', 'K0001V1726_NO-ADISActivatedStates-2019-06-25.xml', 'P1795V0312_NO-ADISActivatedStates-2019-06-25.xml', 'V0001V0632ADISActivatedStates-2019-06-25.xml', 'P1795V0313ADISActivatedStates-2019-06-26.xml', 'U1824V0181ADISActivatedStates-2019-06-26.xml', 'U1824V0182ADISActivatedStates-2019-06-26.xml', 'V0059V0330ADISActivatedStates-2019-06-26.xml', 'P1888V0088ADISActivatedStates-2019-06-27.xml', 'K0001V1727_NO-ADISActivatedStates-2019-06-27.xml', 'F6101V0462_NO-ADISActivatedStates-2019-06-26.xml', 'F6101V0463_NO-ADISActivatedStates-2019-06-27.xml', 'P1795V0314ADISActivatedStates-2019-06-27.xml', 'U1824V0183ADISActivatedStates-2019-06-27.xml', 'V0059V0331ADISActivatedStates-2019-06-27.xml', 'N6464V0241ADISActivatedStates-2019-06-28.xml', 'U1824V0184ADISActivatedStates-2019-06-28.xml', 'V0001V0633ADISActivatedStates-2019-06-28.xml', 'V0001V0634ADISActivatedStates-2019-06-28.xml', 'U1824V0185ADISActivatedStates-2019-07-01.xml', 'N6464V0242_NO-ADISActivatedStates-2019-07-01.xml', 'U1824V0186ADISActivatedStates-2019-07-02.xml', 'N6464V0243ADISActivatedStates-2019-07-02.xml', 'U1824V0187ADISActivatedStates-2019-07-02.xml', 'N6464V0244 ...

# %%
file='M11000V0259ADISActivatedStates-2024-06-11.html'
