# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os

# %%
filepath = "C:/Users/to09267/Documents/A321XLR"
liste_file=os.listdir(filepath)
print (liste_file)
# Out:
# ['A321-flare-compil.csv', 'A321-flare-compil_gmt_fromTSAS.xlsx', 'A321neo XLR - Vcar specification_E070RP1914663_v7.0.pdf', 'A321XLR - Raccourci.lnk', 'A321XLR.pdf', 'A321_CERTIF_EIS.csv', 'A321_df_extract_template.csv', 'A321_XLR_all_app.bdr', 'A321_XLR_all_app.csv', 'A321_XLR_NPA', 'ADIS', 'ADIS_36860_DESCRIPTION.pdf', 'allappA321xlr.xlsx', 'ALLM6839.bdr', 'ALLM6839.csv', 'ALL_APP_XLR - ALL_APP_XLR.dxp', 'ALTSTARSTUDY', 'APFDTCAS', 'APTCAS_S225S2253_PLOTS.pdf', 'ATHR in DIRECT ALTN LAW', 'ATHR IN DIRECT LAW', 'autoland_standard_59.csv', 'bdr_certif_eis_complet.csv', 'BSOFALTA', 'CADV Single Aisle Specific Computations for Studies.pdf', 'Calcul_de_vents', 'calcul_vent_Sandra_XLR_general_parameters', 'Calendrier-A3-2024.pdf', 'Capture_glide_envelope.xlsx', 'CDF_CERTIF', 'comparaison_LOM_GEOM.xlsx', 'compil-comparCUB-TDIF.pdf', 'compil-CUB-V2.pdf', 'Compil-speed_char.csv', 'compilation_FG59_ELAC_XI_R2.pdf', 'Compiled_data_217_cdf.csv', 'Compiled_data_cdf.csv', 'Compiled_data_update_cdf.csv', 'compil_plot_VZ.pdf', 'compil_VZ_VZESTFLARE_VZTP_NERT.pdf', 'Configuration 30253.pdf', 'Configuration 30254.pdf', 'Configuration 30368.pdf', 'configuration 35946.pdf', 'configuration 35947.pdf', 'configuration 35948.pdf', 'configuration 35952.pdf', 'configuration 36593.pdf', 'configuration 36737.pdf', 'config_FMGC_ELAC.xlsx', 'DDAT-Ai429TST_v1.0.pdf', 'definition_paramètres_flight_matching.pdf', 'DFLY-Ai429TST-SHORT-v1.0.pdf', 'dico_ES_COM.xlsx', 'dico_FMGC_ELAC.xlsx', 'DisplayResult_AP_CRUISE_PERFO_172324.csv', 'DisplayResult_LOC_WITH_AP_ENGAGED_201473.dxp', 'DisplayResult_PITCH_WARNING_226448.dxp', 'DisplayResult_PITCH_WARNING_226456.dxp', 'DisplayResult_PITCH_WARNING_227026.dxp', 'E070RP2113342.pdf', 'EVYCC_DEFINITION OF CUB SCREEN AND APTCAS DERI_V22RQ1242451_v1.1.pdf', 'extract_all_app.csv', 'extract_app_tc_certif.csv', 'fcr-e11058-f38-iv.pdf', 'FLARE SYNTHESIS', 'FLARE SYNTHESIS NEW STD XJ-R2', 'Flare_new_plot', 'Flare_new_plot_unitlXI_R4', 'Flare_table.oxps', 'Formule_GMT_DEA_from_BDR.xlsx', 'FTRA_A321_XLR_ Autoland_assessment_with_FG_CE03-59-60_&_ELAC_XI-R2-R4_completed.pdf', 'FTR_CRZ_XLR.xlsx', 'GBAS CAT3 AUTOLAND SIMULATION RESULTS AND VERTICAL MARGIN_X22RP1133178_issue 1.pdf', 'GLS', 'GSCAPTURE.xlsx', 'HPFDREA.pdf', 'ICING', 'LFBO32R.csv', 'LFBO32R.xlsx', 'LFBO32R._profil.csv', 'liste_oscillation_A321.tri', 'liste_param_VZ.tri', 'liste_SPEED_CAR.tri', 'LOCSTARSTUDY', 'log-e6839-f487.pdf', 'LOG-E6839F0485.pdf', 'LOG-E6839F0486.pdf', 'LOG_INGES', 'M11000V0100full.csv', 'M11000V0184full.tri', 'M11000V0185pdf_20231127_105300.000.pdf', 'M11000V0185pdf_20231127_153200.000.pdf', 'M11000V0185pdf_20231127_154300.000.pdf', 'M11000V0185pdf_20240116_113100.000.pdf', 'M11000V0185pdf_20240116_113400.000.pdf', 'M11000V0185pdf_20240126_180000.000.pdf', 'M11000V0185pdf_20240209_141120.000.pdf', 'M11000V0185pdf_20240209_141200.000.pdf', 'M11000V0185pdf_20240313_100716.000.pdf', 'M11000V0222AP009_LDG4.csv', 'M11000V0222AP009_LDG5.csv', 'M11058V0038CRZ.csv', 'M6839V0441full.tri', 'M6839V0494full.tri', 'M6839_V432_V434_V440_V441_autoland_flat_std59.csv', 'M6839_V432_V434_V440_V441_autoland_flat_std59_V2.csv', 'mapping_CRZ_XLR_A400M.xlsx', 'module_36946.pdf', 'NewApp_v3.2 (1).pdf', 'NewApp_v3.2.pdf', 'paramètres_SGA', 'Plot definition', 'plot_certif_inventory_321XLR.xlsx', 'rejeuOCA', 'Resultats - Raccourci.lnk', 'REX', 'RQ0400618_Ed_4.0 Bruits A350-SA.pdf', 'RTF- Bruits A350 Final.pdf', 'S0225S1888full.tri', 'Sandra folder', 'SDD_SA22RP1920605.pdf', 'short_list_flare.xlsx', 'simulation_matching_study', 'SPDPROTECTION', 'Speed_Car', 'SRS_V183_FD_fluctuation_in_turb.pdf', 'State 36860.pdf', 'table_autoland_FG59_ELAC_XI_R2.pdf', 'Table_autoland_FG59_ELAX_XI_R2.xlsx', 'Table_CRZ_TSAS.csv', 'Table_M11058V0038_07072023_1558.csv', 'Table_M6839V0441_12052023_1649.csv', 'TCAS', 'template_for_time_zones.xlsx', 'TEST-2-FTRA', 'to09267_1703206808_TO-longi-XLR_F_auto.pdf', 'to09267_1703266594_internal-parameters-SRS-M11000V183_F_auto.pdf', 'TOLL302205143_Sandra3. ...

# %%
file_name="M11000V0222AP009_LDG5.csv"
data= pd.read_csv(os.path.join(filepath, file_name),sep=';',skiprows=0,header=(0))
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 file_name="M11000V0222AP009_LDG5.csv"
# ----> 2 data= pd.read_csv(os.path.join(filepath, file_name),sep=';',skiprows=0,header=(0))
#       3 data.head()
#
# NameError: name 'pd' is not defined

# %%
df=data.drop(data.index[[0, 1]])

# %%
df.head()
# Out:
#                     GMT          GMTs IR1_L052_PITCH_ACC_1 IR1_L324_PITCH_1  \
# 2  073-09:41:22-000.000  6.255682e+06            0.3671875   2.274169921875
# 3  073-09:41:22-062.500  6.255682e+06           0.82421875  2.2686767578125
# 4  073-09:41:22-125.000  6.255682e+06         -0.150390625   2.252197265625
# 5  073-09:41:22-187.500  6.255682e+06          -0.84765625  2.2357177734375
# 6  073-09:41:22-250.000  6.255682e+06             -0.71875  2.2247314453125
#
#   IR1_L326_BODY_P_RA_1 RA1_RADIO_HEIGHT_BNR RA2_RADIO_HEIGHT_BNR HRA2COR_TD  \
# 2          -0.08203125               130.25                  130          0
# 3           -0.1171875              130.375               130.25          0
# 4          -0.18359375                  128              129.125          0
# 5          -0.24609375              126.625              128.375          0
# 6          -0.23828125                123.5              124.375          0
#
#   NZTFCOR1_TD NZTFCOR2_TD  ...            XP_TP_M VZ1_TD VZ1I_TD VZ2I_TD  \
# 2           0           0  ...  -482.501366465352      0       0       0
# 3           0           0  ...  -482.501366465352      0       0       0
# 4           0           0  ...  -474.750439522322      0       0       0
# 5           0           0  ...  -474.750439522322      0       0       0
# 6           0           0  ...  -467.000015113968      0       0       0
#
#   VZ2_TD CALCVZ2OK_TD CALCVZ1OK_TD   IR1_L364_VERT_ACC_1 IR1_L365_INERT_VS_1  \
# 2      0            0            0   0.00317381997592747                -799
# 3      0            0            0    0.0035400299821049                -799
# 4      0            0            0   0.00219726003706455                -800
# 5      0            0            0  0.000610349990893155                -802
# 6      0            0            0  0.000244139999267645                -801
#
#   Unnamed: 21
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
#
# [5 rows x 22 columns]

# %%
liste = list(df)
print (liste)
# Out:
# ['GMT', 'GMTs', 'IR1_L052_PITCH_ACC_1', 'IR1_L324_PITCH_1', 'IR1_L326_BODY_P_RA_1', 'RA1_RADIO_HEIGHT_BNR', 'RA2_RADIO_HEIGHT_BNR', 'HRA2COR_TD', 'NZTFCOR1_TD', 'NZTFCOR2_TD', 'VZP_TP_I', 'HRA1COR_TD', 'XP_TP_M', 'VZ1_TD', 'VZ1I_TD', 'VZ2I_TD', 'VZ2_TD', 'CALCVZ2OK_TD', 'CALCVZ1OK_TD', 'IR1_L364_VERT_ACC_1', 'IR1_L365_INERT_VS_1', 'Unnamed: 21']

# %%
liste = list(df)

for data in liste:
    typ=type (df[data][2])
    print (data,typ)
# Out:
# GMT <class 'str'>
# GMTs <class 'numpy.float64'>
# IR1_L052_PITCH_ACC_1 <class 'str'>
# IR1_L324_PITCH_1 <class 'str'>
# IR1_L326_BODY_P_RA_1 <class 'str'>
# RA1_RADIO_HEIGHT_BNR <class 'str'>
# RA2_RADIO_HEIGHT_BNR <class 'str'>
# HRA2COR_TD <class 'str'>
# NZTFCOR1_TD <class 'str'>
# NZTFCOR2_TD <class 'str'>
# VZP_TP_I <class 'str'>
# HRA1COR_TD <class 'str'>
# XP_TP_M <class 'str'>
# VZ1_TD <class 'str'>
# VZ1I_TD <class 'str'>
# VZ2I_TD <class 'str'>
# VZ2_TD <class 'str'>
# CALCVZ2OK_TD <class 'str'>
# CALCVZ1OK_TD <class 'str'>
# IR1_L364_VERT_ACC_1 <class 'str'>
# IR1_L365_INERT_VS_1 <class 'str'>
# Unnamed: 21 <class 'numpy.float64'>

# %%
print(liste)
# Out:
# ['GMT', 'GMTs', 'IR1_L052_PITCH_ACC_1', 'IR1_L324_PITCH_1', 'IR1_L326_BODY_P_RA_1', 'RA1_RADIO_HEIGHT_BNR', 'RA2_RADIO_HEIGHT_BNR', 'HRA2COR_TD', 'NZTFCOR1_TD', 'NZTFCOR2_TD', 'VZP_TP_I', 'HRA1COR_TD', 'XP_TP_M', 'VZ1_TD', 'VZ1I_TD', 'VZ2I_TD', 'VZ2_TD', 'CALCVZ2OK_TD', 'CALCVZ1OK_TD', 'IR1_L364_VERT_ACC_1', 'IR1_L365_INERT_VS_1', 'Unnamed: 21']

# %%
liste_num=['IR1_L052_PITCH_ACC_1', 'IR1_L324_PITCH_1', 'IR1_L326_BODY_P_RA_1', 'RA1_RADIO_HEIGHT_BNR', 'RA2_RADIO_HEIGHT_BNR', 'HRA2COR_TD', 'NZTFCOR1_TD', 'NZTFCOR2_TD', 'VZP_TP_I', 'HRA1COR_TD', 'XP_TP_M', 'VZ1_TD', 'VZ1I_TD', 'VZ2I_TD', 'VZ2_TD', 'CALCVZ2OK_TD', 'CALCVZ1OK_TD', 'IR1_L364_VERT_ACC_1', 'IR1_L365_INERT_VS_1']
for data in liste_num:
    typ=type (df[data][2])
    print (data,typ)  
    df[data]=pd.to_numeric(df[data], errors='coerce')
# Out:
# IR1_L052_PITCH_ACC_1 <class 'str'>
# IR1_L324_PITCH_1 <class 'str'>
# IR1_L326_BODY_P_RA_1 <class 'str'>
# RA1_RADIO_HEIGHT_BNR <class 'str'>
# RA2_RADIO_HEIGHT_BNR <class 'str'>
# HRA2COR_TD <class 'str'>
# NZTFCOR1_TD <class 'str'>
# NZTFCOR2_TD <class 'str'>
# VZP_TP_I <class 'str'>
# HRA1COR_TD <class 'str'>
# XP_TP_M <class 'str'>
# VZ1_TD <class 'str'>
# VZ1I_TD <class 'str'>
# VZ2I_TD <class 'str'>
# VZ2_TD <class 'str'>
# CALCVZ2OK_TD <class 'str'>
# CALCVZ1OK_TD <class 'str'>
# IR1_L364_VERT_ACC_1 <class 'str'>
# IR1_L365_INERT_VS_1 <class 'str'>

# %%
df.describe()
# Out:
#                GMTs  IR1_L052_PITCH_ACC_1  IR1_L324_PITCH_1  \
# count  2.090000e+02            209.000000        209.000000
# mean   6.255688e+06              0.097638          4.330900
# std    3.779829e+00              1.099340          2.278398
# min    6.255682e+06             -3.324219          1.999512
# 25%    6.255685e+06             -0.566406          2.411499
# 50%    6.255688e+06              0.099609          3.087158
# 75%    6.255692e+06              0.718750          5.663452
# max    6.255695e+06              3.185547          9.184570
#
#        IR1_L326_BODY_P_RA_1  RA1_RADIO_HEIGHT_BNR  RA2_RADIO_HEIGHT_BNR  \
# count            209.000000            209.000000            209.000000
# mean               0.525867             46.565789             46.580144
# std                0.566809             42.876290             43.252918
# min               -0.308594             -2.250000             -3.000000
# 25%                0.132812              5.375000              4.875000
# 50%                0.304688             36.875000             36.625000
# 75%                0.914062             83.250000             83.500000
# max                1.863281            130.375000            130.250000
#
#        HRA2COR_TD  NZTFCOR1_TD  NZTFCOR2_TD    VZP_TP_I  ...     XP_TP_M  \
# count  209.000000   209.000000   209.000000  209.000000  ...  209.000000
# mean    26.587254     1.424580     1.420792   -9.300185  ...   12.651780
# std     31.073702     1.444481     1.446987    5.888189  ...  287.955951
# min     -1.733906    -0.091015    -0.080978  -14.396095  ... -482.501366
# 25%      0.000000     0.033390     0.007061  -14.013795  ... -235.121342
# 50%     11.795144     0.992516     0.979629  -12.852144  ...   17.834631
# 75%     50.112859     2.828280     2.817279   -5.690082  ...  260.631496
# max     97.156530     5.538617     5.536949    5.555582  ...  507.033388
#
#            VZ1_TD     VZ1I_TD     VZ2I_TD      VZ2_TD  CALCVZ2OK_TD  \
# count  209.000000  209.000000  209.000000  209.000000    209.000000
# mean    -7.266633   -0.259634   -0.255556   -7.241243      0.143541
# std      6.551627    0.635725    0.625740    6.735795      0.351465
# min    -16.775040   -1.808786   -1.780375  -21.599560      0.000000
# 25%    -13.915305    0.000000    0.000000  -13.913509      0.000000
# 50%     -7.152425    0.000000    0.000000   -7.177216      0.000000
# 75%      0.000000    0.000000    0.000000    0.000000      0.000000
# max      5.461867    0.000000    0.000000    5.392213      1.000000
#
#        CALCVZ1OK_TD  IR1_L364_VERT_ACC_1  IR1_L365_INERT_VS_1  Unnamed: 21
# count    209.000000           209.000000           209.000000          0.0
# mean       0.143541             0.041756          -566.727273          NaN
# std        0.351465             0.045680           350.281229          NaN
# min        0.000000            -0.019775          -878.000000          NaN
# 25%        0.000000            -0.001099          -847.000000          NaN
# 50%        0.000000             0.052734          -753.000000          NaN
# 75%        0.000000             0.078613          -348.000000          NaN
# max        1.000000             0.122680           316.000000          NaN
#
# [8 rows x 21 columns]

# %%
#geometrical data A321 XLR
XRA1=32.436
ZRA1=-2.166
XRA2=34.289
ZRA2=-2.156
XTP=24.571
ZTP=-4.48
THETA01=6
THETA02=6
#RATP en m
XRA1TP=XRA1-XTP
ZRA1TP=ZRA1-ZTP
XRA2TP=XRA2-XTP
ZRA2TP=ZRA2-ZTP
#IRTP en feet
XIRTP=54.43
ZIRTP=8.07
degrad=3.141592654/180.
fts2=9.81/0.3048
mft=1/0.3048

# %%
gk_1=5.2
gk_2=26
gk_3=5

# %%
#fonction pour corriger le radioaltimètre
def cor_hra (hra,theta,deltax,deltaz):
    OFFSET_RA_M=(np.cos(theta*degrad)-np.cos(THETA01*degrad))*deltaz-(np.sin(theta*degrad)-np.sin(THETA01*degrad))*deltax
    HRAC=hra-OFFSET_RA_M/0.3048
    return(HRAC)

# %%
#fonction pour l'init des calculs
def binit(hra):
    if (hra>100):
        binit=1
    else:
        binit=0
    return(binit)

# %%
def cor_nz(nzt,pitacc,pitrat,pitch):
    COR_NZ1=pitacc*degrad*(ZIRTP*np.sin(pitch*degrad)-XIRTP*np.cos(pitch*degrad))
    COR_NZ3=pitrat*pitrat*degrad*degrad*(ZIRTP*np.cos(pitch*degrad)-XIRTP*np.sin(pitch*degrad))
    nztcor=nzt*fts2+(COR_NZ1+COR_NZ3)
    return(nztcor)

# %%
GMT="073-09:41:22-000.000"
import re
def find_dates(text, pattern) :
    return re.findall(pattern, text)
text = "La date est le 09/02/2023 et l'autre date est le 12-12-2024"
pattern = r"\b(0[1-9]|1[0-2])[-/](0[1-9]|[12]\d|3[01])[-/](19\d\d|20\d\d)\b"
dates = find_dates(text, pattern)
print("Dates trouvées :", dates)
# Out:
# Dates trouvées : [('09', '02', '2023'), ('12', '12', '2024')]

# %%
#model=r"\d+-\d+:\d+:\d+-\d+.\d+"
model=r"^(\d{3})-(\d{2}):(\d{2}):(\d{2})-(\d{3}).(\d{3})"
dates = find_dates(GMT, model)[0]
print (dates)
(DD,HH,MM,SS,MS,MUS)=dates
print(DD,HH,MM,SS,MS,MUS)
GMT_S=float(HH)*3600+float(MM)*60+float(SS)+float(MS)/1000.
print(GMT_S)
# Out:
# ('073', '09', '41', '22', '000', '000')
# 073 09 41 22 000 000
# 34882.0

# %%
#GMT="073-09:41:22-000.000"
def  convert_GMT(GMT):
    model=r"^(\d{3})-(\d{2}):(\d{2}):(\d{2})-(\d{3}).(\d{3})"
    dates = find_dates(GMT, model)[0]
    (DD,HH,MM,SS,MS,MUS)=dates
    GMT_S=float(HH)*3600+float(MM)*60+float(SS)+float(MS)/1000.
    return GMT_S

# %%
def third_order_filter(z,zpp,binit,vzinit,deltat):
    if binit==1:
        estz=z
        eps=0
        eint1=vzinit
        estvz=vzinit/60
        eint3=g_k3*eps
        estbias=0
        eint2=zpp-((g_k2*eps)+estbias)
        estbiasp=estbias
        estvzp=estvz
        estzp=estz
        eint1p=eint1
    else:
            eps=estzp-z
            eint3=g_k3*eps
            estbias=estbiasp+eint3*deltat
            eint2=zpp-((g_k2*eps)+estbias)
            estvz=estvzp+eint2*deltat
            eint1=estvz-g_k1*eps
            estz=estzp+eint1*deltat
            estbiasp=estbias
            estvzp=estvz
            estzp=estz
            eint1p=eint1
#    return (eint1,eint2,eint3,estz,estvz,eps,estbias)
    return (eint1,eint2,eint3,estz,estvz,eps,estbias)

# %%
#cor_hra (hra,theta,deltax,deltaz)
df[['HRACOR1']]=df.apply(lambda row: pd.Series(cor_hra(row["RA1_RADIO_HEIGHT_BNR"],row["IR1_L324_PITCH_1"],XRA1TP,ZRA1TP)),axis=1)

# %%
df[['HRACOR2']]=df.apply(lambda row: pd.Series(cor_hra(row["RA2_RADIO_HEIGHT_BNR"],row["IR1_L324_PITCH_1"],XRA1TP,ZRA1TP)),axis=1)

# %%
df[["GMT_S"]]=df.apply(lambda row: pd.Series(convert_GMT(row["GMT"])),axis=1)
df[["BINIT"]]=df.apply(lambda row: pd.Series(binit(row["RA2_RADIO_HEIGHT_BNR"])),axis=1)

# %%
df.tail()
# Out:
#                       GMT          GMTs  IR1_L052_PITCH_ACC_1  \
# 206  073-09:41:34-750.000  6.255695e+06              2.292969
# 207  073-09:41:34-812.500  6.255695e+06              1.488281
# 208  073-09:41:34-875.000  6.255695e+06              1.050781
# 209  073-09:41:34-937.500  6.255695e+06              0.521484
# 210  073-09:41:35-000.000  6.255695e+06              1.179688
#
#      IR1_L324_PITCH_1  IR1_L326_BODY_P_RA_1  RA1_RADIO_HEIGHT_BNR  \
# 206          8.909912              1.058594                 0.625
# 207          8.975830              1.070312                 0.750
# 208          9.041748              1.125000                 1.125
# 209          9.113159              1.175781                 1.500
# 210          9.184570              1.246094                 1.750
#
#      RA2_RADIO_HEIGHT_BNR  HRA2COR_TD  NZTFCOR1_TD  NZTFCOR2_TD  ...  \
# 206                 0.000    1.707556     3.385577     3.359594  ...
# 207                 0.375    1.987812     3.262159     3.239977  ...
# 208                 0.500    2.354125     3.144034     3.137662  ...
# 209                 0.875    2.574986     3.136534     3.124635  ...
# 210                 1.000    2.897998     3.152812     3.146943  ...
#
#        VZ2_TD  CALCVZ2OK_TD  CALCVZ1OK_TD  IR1_L364_VERT_ACC_1  \
# 206  4.400057             1             1             0.117309
# 207  4.547973             1             1             0.118408
# 208  4.959626             1             1             0.119507
# 209  5.124112             1             1             0.121582
# 210  5.392213             1             1             0.122680
#
#      IR1_L365_INERT_VS_1  Unnamed: 21   HRACOR1   HRACOR2      GMT_S  BINIT
# 206                  256          NaN  1.974316  1.349316  34894.750      0
# 207                  271          NaN  2.130000  1.755000  34894.812      0
# 208                  286          NaN  2.535688  1.910688  34894.875      0
# 209                  302          NaN  2.943939  2.318939  34894.937      0
# 210                  316          NaN  3.227195  2.477195  34895.000      0
#
# [5 rows x 26 columns]

# %%
#filtering données ADIRUS
binit=1
deltat=62.5
tau=500
a=2*tau/deltat
for elem in df.index:
    print (elem)
    nzt1= df.loc [elem,"IR1_L364_VERT_ACC_1"]
    pitacc1=df.loc [elem,"IR1_L052_PITCH_ACC_1"]
    pitrat1=df.loc [elem,"IR1_L326_BODY_P_RA_1"]
    if binit==1:
        nztf1=nzt1
        pitaccf1=pitacc1
        pitratf1=pitrat1

        binit=0
    else:
        nztf1=(a-1)/(a+1)*nztf1p+1/(a+1)*(nzt1+nzt1p)
        pitaccf1=(a-1)/(a+1)*pitaccf1p+1/(a+1)*(pitacc1+pitacc1p)
        pitratf1=(a-1)/(a+1)*pitratf1p+1/(a+1)*(pitrat1+pitrat1p)
            
    nzt1p=nzt1
    pitacc1p=pitacc1
    pitrat1p=pitrat1
    nztf1p=nztf1
    pitaccf1p=pitaccf1
    pitratf1p=pitratf1  
        
    df.loc [elem,"NZTF1"]=nztf1
    df.loc [elem,"PITACCF1"]=pitaccf1
    df.loc [elem,"PITRATF1"]=pitratf1
    
    print(elem,nztf1,pitaccf1,pitratf1)
# Out:
# 2
# 2 0.0031738199759274 0.3671875 -0.08203125
# 3
# 3 0.003195361740996665 0.39407169117647056 -0.08409926470588235
# 4
# 4 0.00315692447847761 0.38734726427335636 -0.09189824826989618
# 5
# 5 0.0029506751297130444 0.28306835818237325 -0.10636242494402603
# 6
# 6 0.002653800996226845 0.15762465427856462 -0.1223418455388465
# 7
# 7 0.0023990338208838276 0.09553737877520407 -0.13483287841662925
# 8
# 8 0.002095252782769413 0.09038684156635653 -0.1474628338970258
# 9
# 9 0.0016333348046921818 0.054592249911491045 -0.16389183873266983
# 10
# 10 0.0011683154158673896 -0.004679632431037313 -0.1788475782935322
# 11
# 11 0.0008657130157800497 -0.01906474920385645 -0.18905668672958723
# 12
# 12 0.0007423226606190203 0.01661106687895019 -0.19346913534963578
# 13
# 13 0.0005903652876913532 0.07037833106966193 -0.19736247236732568
# 14
# 14 0.00019778407192405873 0.05509025535558405 -0.2042444609123462
# 15
# 15 -0.0002706811159526835 0.03309893854904475 -0.20457231845207016
# 191 0.10195461938719808 -0.839957981960379 0.7148426774843571
# 192
# 192 0.10364615943450135 -0.5244574105532755 0.6989880242509033
# 193
# 193 0.10516741719682778 -0.3102978990175961 0.6900537713978558
# 194
# 194 0.10676820485766993 -0.1186911608978789 0.6966467100569316
# 195
# 195 0.10841762370025645 0.07909603450187155 0.709587170638469
# 196
# 196 0.109916076468681 0.2057051407369455 0.7278986064457079
# 197
# 197 0.11100128153427094 0.2579061903561284 0.7371623733344481
# 198
# 198 0.11164286960103624 0.18195307237305447 0.7372940058833366
# 199
# 199 0.11197201713865744 0.08104315209387158 0.7378697110735323
# 200
# 200 0.1119608568351562 0.00923844302400434 0.7298758480060579
# 201
# 201 0.11172123053504218 -0.08697710909646675 0.7200650864759334
# 202
# 202 0.11154569859744157 -0.09512686096747067 0.7178423557140589
# 203
# 203 0.11140517868926456 -0.03441800232423882 0.7165704609241695
# 204
# 204 0.11125246810852013 0.015357277360965746 0.7188948919919144
# 205
# 205 0.11129723820562329 0.09305421531849918 0.735651742934042
# 206
# 206 0.11173885432652837 0.2651259620457346 0.7651430820006253
# 207
# 207 0.1124588226375528 0.4563611429815305 0.8003560282358458
# 208
# 208 0.1132233392751873 0.552028214395468 0.8353325249139816
# 209
# 209 0.1140846081127718 0.5795699318195306 0.8723981837476308
# 210
# 210 0.11503124653854746 0.6114541677819388 0.9122263386008507

# %%
sns.lineplot(x="GMT_S", y="NZTF1",data=df)
sns.lineplot(x="GMT_S", y="IR1_L364_VERT_ACC_1",data=df)

plt.show()

# %%
sns.lineplot(x="GMT_S", y="PITACCF1",data=df)
sns.lineplot(x="GMT_S", y="IR1_L052_PITCH_ACC_1",data=df)

plt.show()

# %%
sns.lineplot(x="GMT_S", y="PITRATF1",data=df)
sns.lineplot(x="GMT_S", y="IR1_L326_BODY_P_RA_1",data=df)

plt.show()

# %%
df[['NZTFCOR1']]=df.apply(lambda row: pd.Series(cor_nz(row["IR1_L364_VERT_ACC_1"],row["IR1_L052_PITCH_ACC_1"],row["IR1_L326_BODY_P_RA_1"],row["IR1_L324_PITCH_1"])),axis=1)  
df[['NZTFCOR1F']]=df.apply(lambda row: pd.Series(cor_nz(row["NZTF1"],row["PITACCF1"],row["PITRATF1"],row["IR1_L324_PITCH_1"])),axis=1)

# %%
#filtre complementaire

# %%
sns.lineplot(x="GMT_S", y="HRA2COR_TD",data=df)
sns.lineplot(x="GMT_S", y="HRACOR2",data=df)
sns.lineplot(x="GMT_S", y="HRACOR1",data=df)
#sns.lineplot(x="GMT_S", y="IR1_L324_PITCH_1",data=df)
plt.show()

# %%
print (list(df))
# Out:
# ['GMT', 'GMTs', 'IR1_L052_PITCH_ACC_1', 'IR1_L324_PITCH_1', 'IR1_L326_BODY_P_RA_1', 'RA1_RADIO_HEIGHT_BNR', 'RA2_RADIO_HEIGHT_BNR', 'HRA2COR_TD', 'NZTFCOR1_TD', 'NZTFCOR2_TD', 'VZP_TP_I', 'HRA1COR_TD', 'XP_TP_M', 'VZ1_TD', 'VZ1I_TD', 'VZ2I_TD', 'VZ2_TD', 'CALCVZ2OK_TD', 'CALCVZ1OK_TD', 'IR1_L364_VERT_ACC_1', 'IR1_L365_INERT_VS_1', 'Unnamed: 21', 'HRACOR1', 'HRACOR2', 'GMT_S', 'BINIT', 'NZTF1', 'PITACCF1', 'PITRATF1', 'NZTFCOR1', 'NZTFCOR1F']

# %%
for elem in df.index:

    binit=df.loc [elem,"BINIT"]
    z=df.loc [elem,"HRACOR1"]
    zpp=df.loc [elem,"NZTFCOR1F"]
#    z=df.loc [elem,"HRA1COR_TD"]
#    zpp=df.loc [elem,"NZTFCOR1_TD"]
    vzinit=df.loc [elem,"IR1_L365_INERT_VS_1"]/60
    deltat=62.5/1000
    if binit==1:
        estz=z
        eps=0
        eint1=vzinit
        estvz=vzinit
        eint3=gk_3*eps
        estbias=0
        eint2=zpp-((gk_2*eps)+estbias)

    else:
            eps=estzp-z
            eint3=gk_3*eps
            estbias=estbiasp+eint3*deltat
            eint2=zpp-((gk_2*eps)+estbias)
            estvz=estvzp+eint2*deltat
            eint1=estvz-gk_1*eps
            estz=estzp+eint1*deltat

    estbiasp=estbias
    estvzp=estvz
    estzp=estz
    eint1p=eint1
    

    df.loc [elem,"ESTBIAS"]=estbias
    df.loc [elem,"ESTVZ"]=estvz
    df.loc [elem,"ESTZ"]=estz
    df.loc [elem,"EINT1"]=eint1
    df.loc [elem,"EINT2"]=eint2
    df.loc [elem,"EINT3"]=eint3

# %%
df.tail()
# Out:
#                       GMT          GMTs  IR1_L052_PITCH_ACC_1  \
# 206  073-09:41:34-750.000  6.255695e+06              2.292969
# 207  073-09:41:34-812.500  6.255695e+06              1.488281
# 208  073-09:41:34-875.000  6.255695e+06              1.050781
# 209  073-09:41:34-937.500  6.255695e+06              0.521484
# 210  073-09:41:35-000.000  6.255695e+06              1.179688
#
#      IR1_L324_PITCH_1  IR1_L326_BODY_P_RA_1  RA1_RADIO_HEIGHT_BNR  \
# 206          8.909912              1.058594                 0.625
# 207          8.975830              1.070312                 0.750
# 208          9.041748              1.125000                 1.125
# 209          9.113159              1.175781                 1.500
# 210          9.184570              1.246094                 1.750
#
#      RA2_RADIO_HEIGHT_BNR  HRA2COR_TD  NZTFCOR1_TD  NZTFCOR2_TD  ...  \
# 206                 0.000    1.707556     3.385577     3.359594  ...
# 207                 0.375    1.987812     3.262159     3.239977  ...
# 208                 0.500    2.354125     3.144034     3.137662  ...
# 209                 0.875    2.574986     3.136534     3.124635  ...
# 210                 1.000    2.897998     3.152812     3.146943  ...
#
#      PITACCF1  PITRATF1  NZTFCOR1  NZTFCOR1F   ESTBIAS     ESTVZ      ESTZ  \
# 206  0.265126  0.765143  1.673472   3.353196 -0.364731  4.751077  2.219058
# 207  0.456361  0.800356  2.446958   3.201192 -0.336900  4.827487  2.491832
# 208  0.552028  0.835333  2.883536   3.138292 -0.350605  5.116809  2.825886
# 209  0.579570  0.872398  3.435323   3.140964 -0.387497  5.529174  3.209827
# 210  0.611454  0.912226  2.868337   3.142425 -0.392924  5.778357  3.576619
#
#         EINT1     EINT2     EINT3
# 206  5.153210  5.728593 -0.386667
# 207  4.364383  1.222571  0.445293
# 208  5.344860  4.629151 -0.219280
# 209  6.143050  6.597840 -0.590265
# 210  5.868674  3.986933 -0.086843
#
# [5 rows x 37 columns]

# %%
sns.lineplot(x="GMT_S", y="ESTZ",data=df)
sns.lineplot(x="GMT_S", y="HRA2COR_TD",data=df)
sns.lineplot(x="GMT_S", y="HRACOR2",data=df)
sns.lineplot(x="GMT_S", y="HRACOR1",data=df)
#sns.lineplot(x="GMT_S", y="IR1_L324_PITCH_1",data=df)
plt.show()

# %%
sns.lineplot(x="GMT_S", y="NZTFCOR1_TD",data=df)
sns.lineplot(x="GMT_S", y="NZTFCOR2_TD",data=df)
sns.lineplot(x="GMT_S", y="NZTFCOR1",data=df)
sns.lineplot(x="GMT_S", y="NZTFCOR1F",data=df)

plt.show()

# %%
print (type(df.index))
for elem in df.index:
    print (elem)
    hra1= df.loc [elem,"RA1_RADIO_HEIGHT_BNR"]
    hra2=df.loc [elem,"RA2_RADIO_HEIGHT_BNR"]
    pitch=df.loc [elem,"IR1_L324_PITCH_1"]
    hrac1=cor_hra (hra1,pitch,XRA1TP,ZRA1TP)
    hrac2=cor_hra (hra2,pitch,XRA2TP,ZRA2TP)
    df.loc [elem,"HRAC1"]=hrac1
    df.loc [elem,"HRAC2"]=hrac2
    print (hra1,hrac1,hra2,hrac2)
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>
# 2
# 130.25 128.54108764980276 130.0 127.8967023491633
# 3
# 130.375 128.66358683706977 130.25 128.14361901489875
# 4
# 128.0 126.28108476099719 129.125 127.00936936278846
# 5
# 126.625 124.89858322859682 128.375 126.25012023729842
# 6
# 123.5 121.76858250934315 124.375 122.24395444658302
# 7
# 122.875 121.13858203218123 122.125 119.98778889048782
# 8
# 123.875 122.1310817707626 123.625 121.47854099675376
# 9
# 124.5 122.74858205508458 124.5 122.34429363219026
# 10
# 122.375 120.61608288576758 123.75 121.58504679756227
# 11
# 122.5 120.733584263432 121.25 119.07580049363477
# 12
# 120.625 118.85108618869815 121.0 118.81655472117268
# 13
# 119.875 118.09608777673841 121.375 119.18539116850087
# 14
# 119.0 117.21359061605251 121.375 119.17614628351411
# 15
# 116.875 115.08359281403237 121.375 119.1699833232007
# 16
# 115.875 114.07859525630965 120.125 117.91382060022718
# 17
# 116.5 114.70109656911724 117.25 115.0357393278137
# 18
# 116.25 114.44859794306808 116.875 114.65765811482017
# 19
# 116.75 114.94609937818515 116.0 113.7795769612749
# 20
# 117.375 115.57109937818515 115.625 113.4045769612749
# 21
# 116.625 114.82109937818515 115.5 113.2795769612749
# 22
# 116.5 114.69609937818515 115.375 113.1545769612749
# 23
# 112.5 110.69360087449142 113.625 111.40149586720621
# 24
# 110.375 108.56610243200984 111.375 109.14841483264243
# 25
# 110.125 108.311105730775 110.75 108.51725294214289
# 26
# 110.375 108.55860747206768 110.125 107.88917208626376
# 27
# 109.875 108.05361113858804 111.5 109.25801055338837
# 28
# 110.0 108.17361505050815 112.5 110.25184925921228
# 29
# 110.0 108.16861920801172 110.25 107.99568820396199
# 30
# 108.375 106.54361920801172 108.875 106.62068820396199
# 31
# 106.375 104.5411213789147 105.0 102.74260776600482
# 32
# 106.0 104.16861920801172 104.25 101.99568820396199
# 33
# 102.25 100.42111709855052 103.375 101.12376870170725
# 34
# 102.125 100.30111306386165 103.125 100.87992987644876
# 35
# 101.25 99.43360747206768 100.875 98.63917208626376
# 36
# 100.25 98.44609937818515 99.375 97.1545769612749
# 37
# 98.75 96.95609400462234 98.625 96.41690193203229
# 38
# 98.5 96.7160896086167 100.0 97.80422785260247
# 39
# 98.625 96.85358548605983 99.5 97.31963658622779
# 40
# 97.5 95.73858328418271 97.25 95.08196463724862
# 41
# 94.5 92.74858205508458 99.375 97.21929363219026
# 42
# 93.375 91.63608188444213 97.625 95.48470620049363
# 43
# 92.625 90.89608283872 94.875 92.74703731262736
# 44
# 92.5 90.78358539264401 93.875 91.76245252168299
# 45
# 91.5 89.79108764980275 91.25 89.1467023491633
# 46
# 90.875 89.17609150366556 90.625 88.53403626993807
# 47
# 89.625 87.93359502649645 89.75 87.6682873226279
# 48
# 88.75 87.06609909072372 89.0 86.92753889913207
# 49
# 87.875 86.19860369572662 88.125 86.06179099868523
# 50
# 87.25 85.58110884088428 87.75 85.69604362052195
# 51
# 86.0 84.33361067586392 86.375 84.32412794373158
# 52
# 85.5 83.84111654026218 84.875 82.83338126075576
# 53
# 84.0 82.34862294336644 84.25 82.21763509827744
# 54
# 83.25 81.60362751107706 83.5 81.47380461207914
# 55
# 82.25 80.61113481064471 82.875 80.85805931539545
# 56
# 81.625 79.98863736320905 81.5 79.48614433175115
# 57
# 80.5 78.87114537870532 80.625 78.62039972617198
# 58
# 79.75 78.12615102030887 79.75 77.75157027663043
# 59
# 78.5 76.88115690004919 79.375 77.38274105683317
# 60
# 78.125 76.51616937320398 77.625 75.64508330556397
# 61
# 76.75 75.14367264004056 76.625 74.64816901098234
# 62
# 76.125 74.52618279669713 76.375 74.40742647054925
# 63
# 75.0 73.4061898643604 75.125 73.16359839607006
# 64
# 74.25 72.6637009102334 74.375 72.42285671249822
# 65
# 73.125 71.54370857013232 73.375 71.42902920855069
# 66
# 72.625 71.05122050349576 72.625 70.68828837971259
# 67
# 71.625 70.05622875447958 71.5 69.56946144487834
# 68
# 71.0 69.44124596459825 70.625 68.70680825672724
# 69
# 69.625 68.07375949109432 70.0 68.09106896104792
# 70
# 69.0 67.45627354739152 68.625 66.7253301748894
# 71
# 68.0 66.46378813286825 68.0 66.10959189748549
# 72
# 67.375 65.84630324690285 66.75 64.86885412807003
# 73
# 66.0 64.47380840226424 66.0 64.12194165101876
# 74
# 65.25 63.72881888887364 64.75 62.87811686587679
# 75
# 64.25 62.73382960984501 64.25 62.38429230582636
# 76
# 63.75 62.236335058158865 63.375 61.5123801101395
# 77
# 62.5 60.98884056499413 62.375 60.5154679706404
# 78
# 61.5 59.99134613032776 61.75 59.89355588730064
# 79
# 61.0 59.49385175413675 60.375 58.521643860091864
# 80
# 59.875 58.37135743639805 59.875 58.02473188898567
# 81
# 59.25 57.74886317708863 58.625 56.777819973953676
# 82
# 57.625 56.12636897618546 58.25 56.4059081149675
# 83
# 57.0 55.50638074950575 57.25 55.41208456501907
# 84
# 55.625 54.13889884695723 55.875 54.0463496597304
# 85
# 55.125 53.641404996007864 55.25 53.42443813642302
# 86
# 54.125 52.64641746882113 54.0 52.1806152573212
# 87
# 53.625 52.15143017443013 53.625 51.8117926013807
# 88
# 52.375 50.911456283298165 52.625 50.82414795807516
# 89
# 51.75 50.29397647466721 52.0 50.208415059705175
# 90
# 50.5 49.048990225576205 50.875 49.08959340517984
# 91
# 50.0 48.55400420826718 50.375 48.595771972566546
# 92
# 48.625 47.18903286825764 49.0 47.233129772167395
# 93
# 48.125 46.694047545188404 48.0 46.23930900392718
# 94
# 46.875 45.444047545188404 47.5 45.73930900392718
# 95
# 46.375 44.94154017783093 46.125 44.361219360407674
# 96
# 45.25 43.81403286825764 45.625 43.858129772167395
# 97
# 44.625 43.18652561649157 44.25 42.48004023923475
# 98
# 43.375 41.931511286473295 43.875 42.09886133940592
# 99
# 42.875 41.42900420826718 43.0 41.220771972566546
# 100
# 41.875 40.43401842255577 41.75 39.97695076163812
# 101
# 41.25 39.819047545188404 41.125 39.36430900392718
# 102
# 40.25 38.83158524793176 40.25 38.50475804971915
# 103
# 39.625 38.21912439182229 39.5 37.770208473231726
# 104
# 38.625 37.23919001244106 38.375 36.669932007648725
# 105
# 38.125 36.759259303215906 37.875 36.194659045397074
# 106
# 36.875 35.53686054902061 36.625 34.97866441586363
# 107
# 36.25 34.93444850960208 36.25 34.63149187137755
# 108
# 35.25 33.97210530833435 35.25 33.67788066357205
# 109
# 34.75 33.502239880447405 34.25 32.715000371770195
# 110
# 33.625 32.40738252768598 33.75 32.252127737358016
# 111
# 33.125 31.940046128475373 32.75 31.292357634233163
# 112
# 32.0 30.845205470737366 32.25 30.829500794868576
# 113
# 31.5 30.382915826490837 31.125 29.75094029498099
# 114
# 30.375 29.295638529369526 30.625 29.297391426915897
# 115
# 30.0 28.958373501357173 29.375 28.093854094605323
# 116
# 28.875 27.881188623534822 28.5 27.277723217019
# 117
# 28.25 27.296469044100647 28.0 26.827311307328863
# 118
# 27.125 26.214281959848208 27.0 25.880012632430066
# 119
# 26.625 25.75459045734317 26.5 25.429626913556845
# 120
# 25.5 24.669912422673256 25.375 24.354253714508513
# 121
# 25.0 24.210247760956985 25.125 24.1538929185084
# 122
# 24.0 23.253118604506994 24.125 23.20664803216561
# 123
# 23.625 22.918481224718303 23.5 22.63131244852356
# 124
# 22.75 22.09142882001623 22.5 21.690304578155676
# 125
# 22.25 21.62677033882974 21.75 20.98378321782492
# 126
# 21.25 20.65959629889246 21.25 20.524164334320155
# 127
# 20.375 19.814904691512094 20.25 19.561446073311117
# 128
# 19.875 19.34269367990969 19.75 19.095626744514117
# 129
# 18.75 18.2429615950489 18.875 18.251704816559144
# 130
# 18.375 17.89070693181075 18.375 17.779678912282833
# 131
# 17.75 17.288456242403313 17.75 17.18265661566526
# 132
# 17.25 16.813737894237494 17.5 16.963747158625928
# 133
# 16.5 16.08143794468406 16.75 16.23551315816412
# 134
# 16.0 15.594082291988688 16.125 15.626061615142667
# 135
# 15.375 14.986786407811971 15.625 15.147831287541166
# 136
# 15.125 14.751963243417585 14.75 14.291492701777221
# 137
# 14.375 14.012082094871277 14.375 13.928934510611167
# 138
# 14.125 13.772201713428752 13.75 13.31637701011829
# 139
# 13.5 13.154791929863428 13.5 13.07570933690211
# 140
# 13.0 12.664912887271289 12.875 12.463153040684034
# 141
# 12.375 12.044973652197285 12.125 11.719375149804645
# 142
# 12.0 11.672504106134394 11.875 11.472486268572277
# 143
# 11.5 11.175034607689899 11.25 10.850597430106664
# 144
# 11.25 10.930095753563055 11.0 10.606819881361318
# 145
# 10.5 10.182626397834186 10.375 9.984931171024387
# 146
# 10.25 9.932626397834186 10.0 9.609931171024387
# 147
# 9.75 9.43515708963067 9.375 8.988042503339823
# 148
# 9.25 8.940218615706652 9.125 8.744265295813394
# 149
# 8.625 8.322811260679222 8.5 8.128599803701503
# 150
# 8.375 8.077873260961931 8.125 7.759823021411744
# 151
# 8.0 7.710466616372194 7.75 7.394158166082331
# 152
# 7.75 7.470591751916295 7.25 6.906605618238235
# 153
# 7.125 6.8582492326405395 7.0 6.672165883243792
# 154
# 6.875 6.6209078898657445 6.5 6.187727200257244
# 155
# 6.25 6.00856772068302 6.25 5.953289565702688
# 156
# 6.0 5.788956085491144 5.625 5.365643498974098
# 157
# 5.5 5.314284844817257 5.125 4.89677633839562
# 158
# 5.375 5.2196854675624555 4.875 4.684141176925377
# 159
# 4.75 4.625092719453687 4.375 4.221511893717249
# 160
# 4.625 4.538111045238866 4.125 4.018233480656356
# 161
# 3.875 3.8312108275475643 3.5 3.446195500466915
# 162
# 3.625 3.6243236179237854 3.25 3.249168953547074
# 163
# 3.25 3.2949865058587458 2.875 2.9302707975828834
# 164
# 3.0 3.09066371284614 2.625 2.7363851346987187
# 165
# 2.375 2.53420607396677 2.125 2.3205796993207293
# 166
# 2.125 2.334998496927776 1.75 2.0079635914443554
# 167
# 1.75 2.0082671137675776 1.5 1.817241888289264
# 168
# 1.375 1.684092652417499 1.0 1.3796541906192576
# 169
# 0.875 1.2349348978663937 0.75 1.1920807238392939
# 170
# 0.75 1.1633370317402592 0.375 0.882643648572252
# 171
# 0.5 0.9591246214431706 0.125 0.6888525259461106
# 172
# 0.25 0.7549252968381711 -0.25 0.3700723817735636
# 173
# -0.25 0.3134672080978256 -0.625 0.06692457436378763
# 174
# -0.375 0.2317507381381445 -0.75 -0.004956143411205871
# 175
# -0.625 0.022498484417940445 -1.125 -0.32995301659629095
# 176
# -0.875 -0.18674387325135233 -1.25 -0.40494175947011035
# 177
# -1.125 -0.4010728937525335 -1.5 -0.6111753326014251
# 178
# -1.375 -0.6128457338639578 -1.625 -0.6892760143610699
# 179
# -1.5 -0.7021594163965315 -1.875 -0.8954971308026629
# 180
# -1.75 -0.9190155785529722 -2.0 -0.9798400325206922
# 181
# -1.75 -0.8782145911691032 -2.25 -1.179793645569854
# 182
# -2.0 -1.1027092106282042 -2.375 -1.2735108463726017
# 183
# -2.0 -1.08230228712008 -2.5 -1.373482521790212
# 184
# -2.25 -1.3118930485501084 -2.375 -1.2234523596252582
# 185
# -2.0 -1.0465846075857392 -2.625 -1.454678540945713
# 186
# -1.875 -0.9113782630727908 -3.0 -1.8171620952506966
# 187
# -2.0 -1.0287231292234393 -2.75 -1.5577744648360583
# 188
# -2.25 -1.2710676742508964 -2.375 -1.1733865814471323
# 189
# -2.0 -1.0083078707429969 -2.5 -1.2827395490765214
# 190
# -1.875 -0.8730993889272969 -2.5 -1.270221421200944
# 191
# -2.0 -0.9827856047069108 -2.375 -1.1264433970706758
# 192
# -2.0 -0.967470551194701 -2.25 -0.9826643796834587
# 193
# -1.75 -0.699601391280984 -2.125 -0.8357542789888446
# 194
# -1.625 -0.5541773975210322 -2.25 -0.9357125314968269
# 195
# -1.625 -0.5311977455902392 -2.0 -0.6575385018511486
# 196
# -1.375 -0.2556615171017822 -1.875 -0.5012314862832667
# 197
# -1.25 -0.10256770277734795 -1.75 -0.3417907164987233
# 198
# -1.0 0.1678667526190485 -1.5 -0.06674089639461389
# 199
# -0.875 0.3158581056518517 -1.5 -0.038557868718035015
# 200
# -0.75 0.4587421550710411 -1.25 0.23336370047957078
# 201
# -0.625 0.6016278458737963 -1.125 0.3802865158537063
# 202
# -0.375 0.8720706348862521 -0.875 0.6553426752596669
# 203
# -0.25 1.0175155451989513 -0.75 0.8054004346882326
# 204
# 0.125 1.4129625647846786 -0.5 1.0804597793985664
# 205
# 0.25 1.571193439295758 -0.125 1.4961845576695414
# 206
# 0.625 1.9743161588893257 0.0 1.6556471777979092
# 207
# 0.75 2.1299999326323795 0.375 2.0682460531717743
# 208
# 1.125 2.535688303353216 0.5 2.2308483129746053
# 209
# 1.5 2.9439391787509517 0.875 2.646587855936322
# 210
# 1.75 3.227195349888823 1.0 2.81233124920434

# %%
dfplot=df[(df.GMT_S>34888)]
sns.lineplot(x="GMT_S", y="VZ1_TD",data=dfplot)
sns.lineplot(x="GMT_S", y="VZ1I_TD",data=dfplot)
#sns.lineplot(x="GMT_S", y="VZ2_TD",data=df)
#sns.lineplot(x="GMT_S", y="VZ2I_TD",data=df)
#sns.lineplot(x="GMT_S", y="VZP_TP_I",data=df)
sns.lineplot(x="GMT_S", y="ESTVZ",data=dfplot)
# Out:
# <Axes: xlabel='GMT_S', ylabel='VZ1_TD'>

# %%
sns.pairplot(x_vars="VZ1_TD", y_vars="ESTVZ",hue="BINIT",data=df,size=15, aspect=0.6)
#sns.pairplot(x_vars="VZ2_TD", y_vars="ESTVZ",hue="BINIT",data=df,size=15, aspect=0.6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.pairplot(x_vars="VZ1_TD", y_vars="ESTVZ",hue="BINIT",data=df,size=15, aspect=0.6)
#       2 #sns.pairplot(x_vars="VZ2_TD", y_vars="ESTVZ",hue="BINIT",data=df,size=15, aspect=0.6)
#
# NameError: name 'sns' is not defined

# %%
hra1= df.loc [100,"RA1_RADIO_HEIGHT_BNR"]
pitch= df.loc [100,"IR1_L324_PITCH_1"]
print (hra1,pitch)
# Out:
# 41.875 2.8619384765625

# %%
essai=cor_hra(float(hra1),float(pitch),XRA1TP,ZRA1TP)
print (essai)
# Out:
# 64.04415897466669

# %%
essai=cor_hra(41.875,2.8619384765625,XRA1TP,ZRA1TP)

# %%
print (type(hra1))
# Out:
# <class 'str'>
